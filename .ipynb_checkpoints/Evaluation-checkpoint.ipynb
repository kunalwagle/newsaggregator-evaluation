# %%
from pymongo import MongoClient
client = MongoClient('178.62.27.53', 27017)

# %%
db = client.NewsAggregator

# %%
articles = db.articles
topics = db.topics
clusters = db.summaries
digests = db.digests
users = db.Users

# %% [markdown]
# Labelled Articles Percentages

# %%
june1articles = articles.find({"LastPublished" : { "$regex" : '^2017-06-01' }})
alljune1 = june1articles.count()
print(alljune1)

labelledjune1articles = articles.find({"$and":[{"LastPublished" : { "$regex" : '^2017-06-01' }},{"isLabelled":True}]})                  
labelledjune1 = labelledjune1articles.count()
print(labelledjune1)

print(alljune1-labelledjune1)
print((labelledjune1/alljune1)*100)
# Out:
# 1650
# 1636
# 14
# 99.15151515151514

# %%
june2articles = articles.find({"LastPublished" : { "$regex" : '^2017-06-02' }})
alljune2 = june2articles.count()
print(alljune2)

labelledjune2articles = articles.find({"$and":[{"LastPublished" : { "$regex" : '^2017-06-02' }},{"isLabelled":True}]})                  
labelledjune2 = labelledjune2articles.count()
print(labelledjune2)

print(alljune2-labelledjune2)
print((labelledjune2/alljune2)*100)
# Out:
# 2249
# 1139
# 1110
# 50.6447309915518

# %%
june3articles = articles.find({"LastPublished" : { "$regex" : '^2017-06-03' }})
alljune3 = june3articles.count()
print(alljune3)

labelledjune3articles = articles.find({"$and":[{"LastPublished" : { "$regex" : '^2017-06-03' }},{"isLabelled":True}]})                  
labelledjune3 = labelledjune3articles.count()
print(labelledjune3)

print(alljune3-labelledjune3)
print((labelledjune3/alljune3)*100)
# Out:
# 1589
# 1170
# 419
# 73.63121460037759

# %%
june5articles = articles.find({"LastPublished" : { "$regex" : '^2017-06-05' }})
alljune5 = june5articles.count()
print(alljune5)

labelledjune5articles = articles.find({"$and":[{"LastPublished" : { "$regex" : '^2017-06-05' }},{"isLabelled":True}]})                  
labelledjune5 = labelledjune5articles.count()
print(labelledjune5)

print(alljune5-labelledjune5)
print((labelledjune5/alljune5)*100)
# Out:
# 1976
# 1335
# 641
# 67.56072874493927

# %%
june5articles = articles.find({"LastPublished" : { "$regex" : '^2017-06-05' }})
alljune5 = june5articles.count()
print(alljune5)

labelledjune5articles = articles.find({"$and":[{"LastPublished" : { "$regex" : '^2017-06-05' }},{"isLabelled":True}]})                  
labelledjune5 = labelledjune5articles.count()
print(labelledjune5)

print(alljune5-labelledjune5)
print((labelledjune5/alljune5)*100)
# Out:
# 1976
# 1335
# 641
# 67.56072874493927

# %%
allarticles = articles.count()
print(allarticles)

alllabelledarticles = articles.find({"isLabelled":True})                  
alllabelled = alllabelledarticles.count()
print(alllabelled)

print(allarticles-alllabelled)
print((alllabelled/allarticles)*100)
# Out:
# 8815
# 6229
# 2586
# 70.66364152013614

# %% [markdown]
# Clustered topics percentages

# %%
topiccount = topics.count()
print(topiccount)

clusteredtopics = topics.find({"NeedsClustering":False})
clusteredtopiccount = clusteredtopics.count()
print(clusteredtopiccount)

print(topiccount-clusteredtopiccount)
print((clusteredtopiccount/topiccount)*100)
# Out:
# 49109
# 15420
# 33689
# 31.399539799222136

# %%
unclustered = topics.aggregate([
   {
        "$match":{ "$and":[{"NeedsClustering": False},{"Articles.1":{"$exists":True}}]} 
   },
   {
        "$project": {
            "arraysize": { "$size": "$Articles" }
         }
    },
    {
          "$group": {
              "_id": "null",
              "count": {
                  "$avg": "$arraysize"
              }
          }
    }
])

pprint.pprint(list(unclustered))
# Out:
# [{'_id': 'null', 'count': 4.312315717849852}]

# %%
clustered = topics.aggregate([
   {
        "$match":{ "$and":[{"NeedsClustering": True},{"Articles.1":{"$exists":True}}]} 
   },
   {
        "$project": {
            "arraysize": { "$size": "$Articles" }
         }
    },
    {
          "$group": {
              "_id": "null",
              "count": {
                  "$avg": "$arraysize"
              }
          }
    }
])

pprint.pprint(list(clustered))
# Out:
# [{'_id': 'null', 'count': 7.7420523138833}]

# %%
unclustered = topics.aggregate([
   {
        "$match":{ "$and":[{"NeedsClustering": False},{"Articles.1":{"$exists":True}}]} 
   },
   {
        "$project": {
            "arraysize": { "$size": "$Clusters" }
         }
    },
    {
          "$group": {
              "_id": "null",
              "count": {
                  "$avg": "$arraysize"
              }
          }
    }
])

pprint.pprint(list(unclustered))
# Out:
# [{'_id': 'null', 'count': 2.3220684962576548}]

# %%
clustered = topics.aggregate([
   {
        "$match":{ "$and":[{"NeedsClustering": True},{"Articles.1":{"$exists":True}}]} 
   },
   {
        "$project": {
            "arraysize": { "$size": "$Clusters" }
         }
    },
    {
          "$group": {
              "_id": "null",
              "count": {
                  "$avg": "$arraysize"
              }
          }
    }
])

pprint.pprint(list(clustered))
# Out:
# [{'_id': 'null', 'count': 2.252877263581489}]

# %%
summarisedarticles = clusters.aggregate([
    {"$unwind":"$Articles"},
    {"$group": {
        "_id": "$Articles"
    }}
])
summarisedarticlescount = sum(1 for _ in summarisedarticles)
print(summarisedarticlescount)
print(articles.count())
print((summarisedarticlescount/articles.count())*100)
print((summarisedarticlescount/alllabelledarticles.count())*100)
# Out:
# 2633
# 8856
# 29.731255645889792
# 42.14823115095246

# %%
clusters.count()
# Out:
# 3739

# %%
clusters.aggregate([
  {"$project": { "_id": 0, "Articles": 1 } },
  {"$unwind": "$Articles" },
  {"$group": { "_id": "$Articles", "tags": { "$sum": 1 } }},
  {"$project": { "_id": 0,"Articles": "$_id", "tags": 1 } },
    {"$sort": { "tags": -1 } }
])

# %% [markdown]
# Queries for getting articles

# %%
guardianQuery = clusters.aggregate([
    {
        "$unwind":"$Articles"
    },
    {
        "$lookup":{
            "from":"articles",
            "localField":"Articles",
            "foreignField":"_id",
            "as":"article"
        }
    },
    {
        "$match":{
            "article.Source":"the-guardian-uk"
        }
    },
    {"$group": { "_id": "$_id"}},
    {"$project": { "_id": 1,"Articles": "$_id"} }
])

guardianSummaries = list(map(lambda art: art["Articles"], list(guardianQuery)))

# %%
dmQuery = clusters.aggregate([
    {
        "$unwind":"$Articles"
    },
    {
        "$lookup":{
            "from":"articles",
            "localField":"Articles",
            "foreignField":"_id",
            "as":"article"
        }
    },
    {
        "$match":{
            "article.Source":"daily-mail"
        }
    },
    {"$group": { "_id": "$_id"}},
    {"$project": { "_id": 1,"Articles": "$_id"} }
])

dmSummaries = list(map(lambda art: art["Articles"], list(dmQuery)))

# %%
dmgSummaries = list(set(dmSummaries) & set(guardianSummaries))

dmgQuery = clusters.find({
    "$and":[
        {
            "_id":{
                "$in":dmgSummaries
            }
        }, 
        {
            "Articles.2":{
                "$exists":False
            }
        }
    ]
})

dmgArticles = list(dmgQuery)

import json

dmgsumms = list(map(lambda art: json.loads(art["Summaries"]), dmgArticles))
# Out:
# [{'[http://www.dailymail.co.uk/news/article-4563250/First-Supreme-Court-portrait-Neil-Gorsuch.html,https://www.theguardian.com/commentisfree/2017/jun/01/china-eu-climate-change-may-trump]': [{'absoluteSentencePosition': 0,
#     'identifier': 0,
#     'relatedNodes': [],
#     'sentence': "It was an historic day at America's highest court on Thursday, as the Supreme Court justices gathered for a rare group portrait.",
#     'sentencePosition': 0.0,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 0,
#     'identifier': 13,
#     'relatedNodes': [],
#     'sentence': 'The most important international agreement to tackle climate change is about to be dealt a severe blow – but Theresa May is nowhere to be found.',
#     'sentencePosition': 0.0,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 1,
#     'identifier': 14,
#     'relatedNodes': [],
#     'sentence': 'Donald Trump is expected to withdraw the United States from the Paris agreement, in which 195 countries signed up to ambitious targets to arrest the rise in global temperatures.',
#     'sentencePosition': 0.03225806451612903,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 2,
#     'identifier': 15,
#     'relatedNodes': [],
#     'sentence': 'Such a decision from the US will heighten the risk of a climate disaster, with all the damaging consequences to food supply, the global economy and our security.',
#     'sentencePosition': 0.06451612903225806,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 1,
#     'identifier': 1,
#     'relatedNodes': [],
#     'sentence': 'The justices had their group photo taken to mark the addition of Associate Justice Neil Gorsuch to the court.',
#     'sentencePosition': 0.07692307692307693,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 3,
#     'identifier': 16,
#     'relatedNodes': [],
#     'sentence': 'Related: World urges Donald Trump not to dump Paris climate agreement Experts in the UK have made clear that climate change is a grave threat to national security, and Trump’s own defence secretary has issued the same warning for the US.',
#     'sentencePosition': 0.0967741935483871,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 4,
#     'identifier': 17,
#     'relatedNodes': [],
#     'sentence': 'Donald Trump’s actions put us all in greater peril.',
#     'sentencePosition': 0.12903225806451613,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 2,
#     'identifier': 2,
#     'relatedNodes': [],
#     'sentence': 'The last time that the group gathered for a picture was in 2010, when Elena Kagan was confirmed.',
#     'sentencePosition': 0.15384615384615385,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 5,
#     'identifier': 18,
#     'relatedNodes': [],
#     'sentence': 'Yet in the face of this threat, May is silent.',
#     'sentencePosition': 0.16129032258064516,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 6,
#     'identifier': 19,
#     'relatedNodes': [],
#     'sentence': 'We have a prime minister who is weak on the world stage and complicit in Trump’s world-harming act.',
#     'sentencePosition': 0.1935483870967742,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 3,
#     'identifier': 3,
#     'relatedNodes': [],
#     'sentence': 'President Donald Trump nominated Gorsuch as the replacement for Antonin Scalia, who died last year.',
#     'sentencePosition': 0.23076923076923078,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 4,
#     'identifier': 4,
#     'relatedNodes': [],
#     'sentence': 'Scalia was the most senior associate justice on the court at the time of his death, so his departure has shifted the order of the justices considerably.',
#     'sentencePosition': 0.3076923076923077,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 5,
#     'identifier': 5,
#     'relatedNodes': [],
#     'sentence': "The most senior member of the court now is Gorsuch's own mentor Anthony Kennedy, who takes the seat of honor on Chief Justice John Roberts' right.",
#     'sentencePosition': 0.38461538461538464,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 14,
#     'identifier': 27,
#     'relatedNodes': [],
#     'sentence': 'What’s most disappointing about May’s failure is that Britain played such a pivotal role in securing the agreement May’s lack of leadership on this issue is appalling, but perhaps not all that surprising.',
#     'sentencePosition': 0.45161290322580644,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 6,
#     'identifier': 6,
#     'relatedNodes': [],
#     'sentence': 'Second in seniority is Clarence Thomas, who gets the seat to the left of Roberts.',
#     'sentencePosition': 0.46153846153846156,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 7,
#     'identifier': 7,
#     'relatedNodes': [],
#     'sentence': "Ruth Bader Ginsberg gets the next best seat to Kennedy's right and Stephen Breyer gets a seat for the first time, moving down to the chair to Thomas' left.",
#     'sentencePosition': 0.5384615384615384,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 19,
#     'identifier': 32,
#     'relatedNodes': [],
#     'sentence': 'What’s most disappointing about May’s failure on climate change is that Britain played such a pivotal role in securing international agreement on it in the first place.',
#     'sentencePosition': 0.6129032258064516,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 8,
#     'identifier': 8,
#     'relatedNodes': [],
#     'sentence': 'The fifth and sixth most senior justices on the court are now Samuel Alito and Sonia Sotomayor respectively, who stand and flank Roberts.',
#     'sentencePosition': 0.6153846153846154,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 9,
#     'identifier': 9,
#     'relatedNodes': [],
#     'sentence': 'Gorsuch replaces Elena Kagan as the newbie on the court, standing in the back right of the photo while Kagan shifts to the back left.',
#     'sentencePosition': 0.6923076923076923,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 10,
#     'identifier': 10,
#     'relatedNodes': [],
#     'sentence': "Gorsuch's nomination to the court was somewhat controversial, since Scalia died while President Obama was still in office.",
#     'sentencePosition': 0.7692307692307693,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 11,
#     'identifier': 11,
#     'relatedNodes': [],
#     'sentence': "Obama nominated Merrick Garland as Scalia's replacement, but the Republican-controlled Congress refused to have a hearing until the outcome of the presidential election, which turned in their favor.",
#     'sentencePosition': 0.8461538461538461,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 12,
#     'identifier': 12,
#     'relatedNodes': [],
#     'sentence': 'Gorsuch, 49, was confirmed by Congress on April 7, and sworn in as the 101st Supreme Court associate justice the following day.',
#     'sentencePosition': 0.9230769230769231,
#     'source': 'daily-mail'}],
#   '[http://www.dailymail.co.uk/news/article-4563250/First-Supreme-Court-portrait-Neil-Gorsuch.html]': [{'absoluteSentencePosition': 0,
#     'identifier': 0,
#     'relatedNodes': [],
#     'sentence': "It was an historic day at America's highest court on Thursday, as the Supreme Court justices gathered for a rare group portrait.",
#     'sentencePosition': 0.0,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 1,
#     'identifier': 1,
#     'relatedNodes': [],
#     'sentence': 'The justices had their group photo taken to mark the addition of Associate Justice Neil Gorsuch to the court.',
#     'sentencePosition': 0.07692307692307693,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 2,
#     'identifier': 2,
#     'relatedNodes': [],
#     'sentence': 'The last time that the group gathered for a picture was in 2010, when Elena Kagan was confirmed.',
#     'sentencePosition': 0.15384615384615385,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 3,
#     'identifier': 3,
#     'relatedNodes': [],
#     'sentence': 'President Donald Trump nominated Gorsuch as the replacement for Antonin Scalia, who died last year.',
#     'sentencePosition': 0.23076923076923078,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 4,
#     'identifier': 4,
#     'relatedNodes': [],
#     'sentence': 'Scalia was the most senior associate justice on the court at the time of his death, so his departure has shifted the order of the justices considerably.',
#     'sentencePosition': 0.3076923076923077,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 5,
#     'identifier': 5,
#     'relatedNodes': [],
#     'sentence': "The most senior member of the court now is Gorsuch's own mentor Anthony Kennedy, who takes the seat of honor on Chief Justice John Roberts' right.",
#     'sentencePosition': 0.38461538461538464,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 6,
#     'identifier': 6,
#     'relatedNodes': [],
#     'sentence': 'Second in seniority is Clarence Thomas, who gets the seat to the left of Roberts.',
#     'sentencePosition': 0.46153846153846156,
#     'source': 'daily-mail'}],
#   '[https://www.theguardian.com/commentisfree/2017/jun/01/china-eu-climate-change-may-trump]': [{'absoluteSentencePosition': 0,
#     'identifier': 0,
#     'relatedNodes': [],
#     'sentence': 'The most important international agreement to tackle climate change is about to be dealt a severe blow – but Theresa May is nowhere to be found.',
#     'sentencePosition': 0.0,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 1,
#     'identifier': 1,
#     'relatedNodes': [],
#     'sentence': 'Donald Trump is expected to withdraw the United States from the Paris agreement, in which 195 countries signed up to ambitious targets to arrest the rise in global temperatures.',
#     'sentencePosition': 0.03225806451612903,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 2,
#     'identifier': 2,
#     'relatedNodes': [],
#     'sentence': 'Such a decision from the US will heighten the risk of a climate disaster, with all the damaging consequences to food supply, the global economy and our security.',
#     'sentencePosition': 0.06451612903225806,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 3,
#     'identifier': 3,
#     'relatedNodes': [],
#     'sentence': 'Related: World urges Donald Trump not to dump Paris climate agreement Experts in the UK have made clear that climate change is a grave threat to national security, and Trump’s own defence secretary has issued the same warning for the US.',
#     'sentencePosition': 0.0967741935483871,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 4,
#     'identifier': 4,
#     'relatedNodes': [],
#     'sentence': 'Donald Trump’s actions put us all in greater peril.',
#     'sentencePosition': 0.12903225806451613,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 5,
#     'identifier': 5,
#     'relatedNodes': [],
#     'sentence': 'Yet in the face of this threat, May is silent.',
#     'sentencePosition': 0.16129032258064516,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 6,
#     'identifier': 6,
#     'relatedNodes': [],
#     'sentence': 'We have a prime minister who is weak on the world stage and complicit in Trump’s world-harming act.',
#     'sentencePosition': 0.1935483870967742,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 7,
#     'identifier': 7,
#     'relatedNodes': [],
#     'sentence': 'While our European neighbours are joining with China and other developing countries to confront Trump and strengthen their efforts on climate change, Theresa May hasn’t issued a word of criticism.',
#     'sentencePosition': 0.22580645161290322,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 8,
#     'identifier': 8,
#     'relatedNodes': [],
#     'sentence': 'Whereas France’s new president used his first meeting with Trump to press him to stay in the Paris agreement, our prime minister failed to even mention it during her fawning trip to Washington in January.',
#     'sentencePosition': 0.25806451612903225,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 9,
#     'identifier': 9,
#     'relatedNodes': [],
#     'sentence': 'This is unacceptable.',
#     'sentencePosition': 0.2903225806451613,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 10,
#     'identifier': 10,
#     'relatedNodes': [],
#     'sentence': 'Just as Donald Trump is abrogating America’s responsibility to lead the fight against climate change, Theresa May is evading Britain’s role.',
#     'sentencePosition': 0.3225806451612903,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 11,
#     'identifier': 11,
#     'relatedNodes': [],
#     'sentence': 'Instead of holding hands with Trump at the White House and rolling out the red carpet for him in London, the prime minister must stand up to him and convince him to keep America in the Paris agreement.',
#     'sentencePosition': 0.3548387096774194,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 12,
#     'identifier': 12,
#     'relatedNodes': [],
#     'sentence': 'Instead of the lavish trappings of a state visit, Trump should be greeted with robust British diplomacy.',
#     'sentencePosition': 0.3870967741935484,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 13,
#     'identifier': 13,
#     'relatedNodes': [],
#     'sentence': 'After all, what is the good of a special relationship unless we’re prepared to use it?',
#     'sentencePosition': 0.41935483870967744,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 14,
#     'identifier': 14,
#     'relatedNodes': [],
#     'sentence': 'What’s most disappointing about May’s failure is that Britain played such a pivotal role in securing the agreement May’s lack of leadership on this issue is appalling, but perhaps not all that surprising.',
#     'sentencePosition': 0.45161290322580644,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 15,
#     'identifier': 15,
#     'relatedNodes': [],
#     'sentence': 'One of her first acts as prime minister was to abolish the Department of Energy and Climate Change.',
#     'sentencePosition': 0.4838709677419355,
#     'source': 'the-guardian-uk'}]},
#  {'[http://www.dailymail.co.uk/tvshowbiz/article-4564304/Transgender-model-Andreja-Pejic-goes-summer-stroll.html,https://www.theguardian.com/sustainable-business/2017/jun/02/droughts-flood-feed-farmer-satellites-see-all-but-what-about-climate-change]': [{'absoluteSentencePosition': 0,
#     'identifier': 0,
#     'relatedNodes': [],
#     'sentence': 'From checking water levels in far-flung dams to making sure the sheep aren’t wrecking the paddock, Australian farmers sometimes find themselves needing to be everywhere at once – and, thanks to the latest satellite analysis capabilities, soon they could be.',
#     'sentencePosition': 0.0,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 1,
#     'identifier': 1,
#     'relatedNodes': [],
#     'sentence': 'In May, the Turnbull government allocated $15.3m over two years to deliver Digital Earth Australia, a free open-access set of products (a beta model is currently accessible) that account for complex variations in the atmosphere, sun position and view angle to deliver precise, continually updated imagery into the hands of the public.',
#     'sentencePosition': 0.047619047619047616,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 2,
#     'identifier': 2,
#     'relatedNodes': [],
#     'sentence': 'Developed by Geoscience Australia in coordination with the CSIRO and the National Computational Infrastructure, the project will for the first time provide open access to three decades of historical satellite data captured every two weeks at 25-metre squared resolution, with future images to provide detail down to every 10 square metres of Australia updated every five days.',
#     'sentencePosition': 0.09523809523809523,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 1,
#     'identifier': 22,
#     'relatedNodes': [],
#     'sentence': 'But Andreja Pejic looked every bit the New Yorker as she went for a stroll in the Big Apple on Thursday.',
#     'sentencePosition': 0.1,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 3,
#     'identifier': 3,
#     'relatedNodes': [],
#     'sentence': 'The project will offer datasets including the normalised difference vegetation index and fractional cover to help paint a picture of changes to vegetation, an intertidal extents model that provides a picture of changes to tidal patterns and coastlines, and water observations from space that monitor rivers, lakes, dams and flooding.',
#     'sentencePosition': 0.14285714285714285,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 6,
#     'identifier': 6,
#     'relatedNodes': [],
#     'sentence': 'A survey of those involved found 95% of users thought the technology had the potential to measurably improve the productivity and sustainability of their property.',
#     'sentencePosition': 0.2857142857142857,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 7,
#     'identifier': 7,
#     'relatedNodes': [],
#     'sentence': '“Over 70% of the graziers involved in the trial said they believed the technology would increase their sustainable carry capacity, and it can now be rolled out to every grazier in the country,” Minchin says.',
#     'sentencePosition': 0.3333333333333333,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 8,
#     'identifier': 8,
#     'relatedNodes': [],
#     'sentence': 'A view of Three Rivers in Queensland using the Digital Australia technology.',
#     'sentencePosition': 0.38095238095238093,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 4,
#     'identifier': 25,
#     'relatedNodes': [],
#     'sentence': 'Andreja appeared in high spirits for the stroll, making her way along the street with a smile on his face.',
#     'sentencePosition': 0.4,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 5,
#     'identifier': 26,
#     'relatedNodes': [],
#     'sentence': "It's probable the model is still on a high after being named the first transgender covergirl for GQ magazine in April.",
#     'sentencePosition': 0.5,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 15,
#     'identifier': 15,
#     'relatedNodes': [],
#     'sentence': 'In developing a continually evolving picture of countrywide vegetation cover, water supplies, coastal erosion and the impacts of flood and drought, the technology also has significant potential to analyse the biggest threat to Australian farmers – climate change, which is already reducing farm productivity and potential wheat yields.',
#     'sentencePosition': 0.7142857142857143,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 17,
#     'identifier': 17,
#     'relatedNodes': [],
#     'sentence': 'Despite its potential, the capability to contribute to climate change research is not mentioned in the original project funding announcement by the resources minister, Matthew Canavan, nor in a Geoscience Australia site explaining the benefits of the project.',
#     'sentencePosition': 0.8095238095238095,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 18,
#     'identifier': 18,
#     'relatedNodes': [],
#     'sentence': 'Canavan, who last year expressed “uncertainty” about climate change, told the Guardian in a statement that his announcement “provided examples of some of the practical uses of Digital Earth Australia, not a list of its limitations” and that he expects the technology “will have a wide range of applications, including information about climate change”.',
#     'sentencePosition': 0.8571428571428571,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 19,
#     'identifier': 19,
#     'relatedNodes': [],
#     'sentence': 'For Geoscience Australia’s part, Minchin says the project has applicability in areas such as the monitoring of carbon farming initiatives but that climate change is not a “core focus” of the project, which he says focuses more on ways to help business productivity.',
#     'sentencePosition': 0.9047619047619048,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 20,
#     'identifier': 20,
#     'relatedNodes': [],
#     'sentence': 'The University of Melbourne director of Centre for Spatial Data Infrastructures and Land Administration, Prof Abbas Rajabifard, says the applicability of the project to climate change depends in the end on “the authorities setting up the standardised protocols and specification for the development of analytical tools and applications”.',
#     'sentencePosition': 0.9523809523809523,
#     'source': 'the-guardian-uk'}],
#   '[http://www.dailymail.co.uk/tvshowbiz/article-4564304/Transgender-model-Andreja-Pejic-goes-summer-stroll.html]': [{'absoluteSentencePosition': 0,
#     'identifier': 0,
#     'relatedNodes': [],
#     'sentence': "She's one of Australia's biggest modeling exports.",
#     'sentencePosition': 0.0,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 1,
#     'identifier': 1,
#     'relatedNodes': [],
#     'sentence': 'But Andreja Pejic looked every bit the New Yorker as she went for a stroll in the Big Apple on Thursday.',
#     'sentencePosition': 0.1,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 2,
#     'identifier': 2,
#     'relatedNodes': [],
#     'sentence': 'The 25-year-old transgender model wore a floral blouse and skinny pants which showed off her slender legs during on her walk.',
#     'sentencePosition': 0.2,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 3,
#     'identifier': 3,
#     'relatedNodes': [],
#     'sentence': 'The GQ covergirl accessorised her outfit with suede loafers and a brown leather handbag.',
#     'sentencePosition': 0.3,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 4,
#     'identifier': 4,
#     'relatedNodes': [],
#     'sentence': 'Andreja appeared in high spirits for the stroll, making her way along the street with a smile on his face.',
#     'sentencePosition': 0.4,
#     'source': 'daily-mail'}],
#   '[https://www.theguardian.com/sustainable-business/2017/jun/02/droughts-flood-feed-farmer-satellites-see-all-but-what-about-climate-change]': [{'absoluteSentencePosition': 0,
#     'identifier': 0,
#     'relatedNodes': [],
#     'sentence': 'From checking water levels in far-flung dams to making sure the sheep aren’t wrecking the paddock, Australian farmers sometimes find themselves needing to be everywhere at once – and, thanks to the latest satellite analysis capabilities, soon they could be.',
#     'sentencePosition': 0.0,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 1,
#     'identifier': 1,
#     'relatedNodes': [],
#     'sentence': 'In May, the Turnbull government allocated $15.3m over two years to deliver Digital Earth Australia, a free open-access set of products (a beta model is currently accessible) that account for complex variations in the atmosphere, sun position and view angle to deliver precise, continually updated imagery into the hands of the public.',
#     'sentencePosition': 0.047619047619047616,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 2,
#     'identifier': 2,
#     'relatedNodes': [],
#     'sentence': 'Developed by Geoscience Australia in coordination with the CSIRO and the National Computational Infrastructure, the project will for the first time provide open access to three decades of historical satellite data captured every two weeks at 25-metre squared resolution, with future images to provide detail down to every 10 square metres of Australia updated every five days.',
#     'sentencePosition': 0.09523809523809523,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 3,
#     'identifier': 3,
#     'relatedNodes': [],
#     'sentence': 'The project will offer datasets including the normalised difference vegetation index and fractional cover to help paint a picture of changes to vegetation, an intertidal extents model that provides a picture of changes to tidal patterns and coastlines, and water observations from space that monitor rivers, lakes, dams and flooding.',
#     'sentencePosition': 0.14285714285714285,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 4,
#     'identifier': 4,
#     'relatedNodes': [],
#     'sentence': "Related: Extreme weather is hurting Australian farmers – it's time to demand action Geoscience Australia’s environmental geoscience division chief, Dr Stuart Minchin, says that, along with the mining sector and environmental studies, agriculture would particularly benefit from world-leading landscape monitoring capabilities, citing the popularity of the technology in an Australia-wide trial.",
#     'sentencePosition': 0.19047619047619047,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 5,
#     'identifier': 5,
#     'relatedNodes': [],
#     'sentence': 'By the conclusion of the NRM Spatial Hub study last year, farmers on 300 properties covering an area of more than 50 million hectares were using satellite data to analyse the vegetation condition of their properties to see where feed was available and not being used, and move water points accordingly to encourage livestock to migrate to those areas.',
#     'sentencePosition': 0.23809523809523808,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 6,
#     'identifier': 6,
#     'relatedNodes': [],
#     'sentence': 'A survey of those involved found 95% of users thought the technology had the potential to measurably improve the productivity and sustainability of their property.',
#     'sentencePosition': 0.2857142857142857,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 7,
#     'identifier': 7,
#     'relatedNodes': [],
#     'sentence': '“Over 70% of the graziers involved in the trial said they believed the technology would increase their sustainable carry capacity, and it can now be rolled out to every grazier in the country,” Minchin says.',
#     'sentencePosition': 0.3333333333333333,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 8,
#     'identifier': 8,
#     'relatedNodes': [],
#     'sentence': 'A view of Three Rivers in Queensland using the Digital Australia technology.',
#     'sentencePosition': 0.38095238095238093,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 9,
#     'identifier': 9,
#     'relatedNodes': [],
#     'sentence': 'Fractional cover can provide insights into areas of dry or dying vegetation and bare soil, as well as allowing the mapping of living vegetation.',
#     'sentencePosition': 0.42857142857142855,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 10,
#     'identifier': 10,
#     'relatedNodes': [],
#     'sentence': 'Photograph: Digital Earth Australia He also notes that the technology is also able to monitor how quickly crops are drying out, allowing farmers to adjust schedules for water and fertiliser application across large areas accordingly.',
#     'sentencePosition': 0.47619047619047616,
#     'source': 'the-guardian-uk'}]},
#  {'[http://www.dailymail.co.uk/news/article-4564996/Cuomo-orders-WTC-lit-green-support-Paris-Accord.html,https://www.theguardian.com/technology/2017/jun/02/shortsighted-wrong-apple-facebook-among-tech-giants-to-reject-paris-pullout]': [{'absoluteSentencePosition': 0,
#     'identifier': 0,
#     'relatedNodes': [],
#     'sentence': 'New York Governor Andrew Cuomo ordered two landmarks in his state lit up green late Thursday as a sign of support for the Paris Agreement on climate change – hours after President Donald Trump announced he was pulling the US out of the accord.',
#     'sentencePosition': 0.0,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 1,
#     'identifier': 1,
#     'relatedNodes': [],
#     'sentence': "The antenna atop the World Trade Center in lower Manhattan and the Kosciuszko Bridge linking Brooklyn and Queens were specially lit 'to show our support for the Paris Accord and demonstrate New York's leadership role in protecting our citizens, our environment, and our planet,' Cuomo said in a statement.",
#     'sentencePosition': 0.030303030303030304,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 2,
#     'identifier': 2,
#     'relatedNodes': [],
#     'sentence': 'The World Trade Center is owned by the Port Authority of New York and New Jersey, a government agency jointly controlled by the governors of the two neighboring states.',
#     'sentencePosition': 0.06060606060606061,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 2,
#     'identifier': 35,
#     'relatedNodes': [],
#     'sentence': '“Decision to withdraw from the #ParisAgreeement was wrong for our planet,” said Apple CEO Tim Cook tweeted on Thursday.',
#     'sentencePosition': 0.08,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 3,
#     'identifier': 3,
#     'relatedNodes': [],
#     'sentence': 'The Kosciuszko Bridge, which spans Newtown Creek and is accessible through the Brooklyn-Queens Expressway, is maintained by the New York State Department of Transportation.',
#     'sentencePosition': 0.09090909090909091,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 3,
#     'identifier': 36,
#     'relatedNodes': [],
#     'sentence': '“Apple is committed to fight climate change and we will never waver.”',
#     'sentencePosition': 0.12,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 4,
#     'identifier': 4,
#     'relatedNodes': [],
#     'sentence': 'Another New York landmark in Lower Manhattan, City Hall, was also lit up in green late Thursday.',
#     'sentencePosition': 0.12121212121212122,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 5,
#     'identifier': 5,
#     'relatedNodes': [],
#     'sentence': 'Mayor Bill de Blasio tweeted a photo of City Hall on Thursday night.',
#     'sentencePosition': 0.15151515151515152,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 4,
#     'identifier': 37,
#     'relatedNodes': [],
#     'sentence': 'Twitter CEO Jack Dorsey called the decision “incredibly shortsighted” and a “move backwards by the federal government”.',
#     'sentencePosition': 0.16,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 6,
#     'identifier': 6,
#     'relatedNodes': [],
#     'sentence': "In the caption, he wrote that New York 'will honor the goals of the Paris Agreement.'",
#     'sentencePosition': 0.18181818181818182,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 7,
#     'identifier': 7,
#     'relatedNodes': [],
#     'sentence': "Earlier on Thursday, de Blasio tweeted that 'opting out of Paris Accord is a grave error.",
#     'sentencePosition': 0.21212121212121213,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 6,
#     'identifier': 39,
#     'relatedNodes': [],
#     'sentence': 'This is an incredibly shortsighted move backwards by the federal government.',
#     'sentencePosition': 0.24,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 8,
#     'identifier': 8,
#     'relatedNodes': [],
#     'sentence': "'Climate change is real - we feel the effects now.",
#     'sentencePosition': 0.24242424242424243,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 9,
#     'identifier': 9,
#     'relatedNodes': [],
#     'sentence': "Trump's choice ensures it will only get worse.'",
#     'sentencePosition': 0.2727272727272727,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 10,
#     'identifier': 10,
#     'relatedNodes': [],
#     'sentence': 'Cuomo, a Democrat, slammed Trump for pulling out of the agreement.',
#     'sentencePosition': 0.30303030303030304,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 11,
#     'identifier': 11,
#     'relatedNodes': [],
#     'sentence': "'The White House's reckless decision to withdraw from the Paris Accord has devastating repercussions not only for the United States, but for our planet,' the governor said.",
#     'sentencePosition': 0.3333333333333333,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 12,
#     'identifier': 12,
#     'relatedNodes': [],
#     'sentence': "'This administration is abdicating its leadership and taking a backseat to other countries in the global fight against climate change.",
#     'sentencePosition': 0.36363636363636365,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 13,
#     'identifier': 13,
#     'relatedNodes': [],
#     'sentence': "'New York State is committed to meeting the standards set forth in the Paris Accord regardless of Washington's irresponsible actions.",
#     'sentencePosition': 0.3939393939393939,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 14,
#     'identifier': 14,
#     'relatedNodes': [],
#     'sentence': "'We will not ignore the science and reality of climate change.'",
#     'sentencePosition': 0.42424242424242425,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 15,
#     'identifier': 15,
#     'relatedNodes': [],
#     'sentence': "Cuomo also announced that he and two of his fellow governors – California's Jerry Brown and Washington State's Jay Inslee – formed the US Climate Alliance, which will 'convene US states committed to upholding the Paris Climate Agreement and taking aggressive action on climate change.'",
#     'sentencePosition': 0.45454545454545453,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 16,
#     'identifier': 16,
#     'relatedNodes': [],
#     'sentence': "So far, 30 states announced Thursday that they would disregard Trump's order on Thursday and pursue their own policies which seek to limit greenhouse gas emissions, according to The Washington Post.",
#     'sentencePosition': 0.48484848484848486,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 17,
#     'identifier': 17,
#     'relatedNodes': [],
#     'sentence': 'Cuomo has made climate change policy a central pillar of his administration.',
#     'sentencePosition': 0.5151515151515151,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 18,
#     'identifier': 18,
#     'relatedNodes': [],
#     'sentence': 'The governor announced a $1.65billion plan to invest in renewable energy and energy efficiency – the largest ever by an American state.',
#     'sentencePosition': 0.5454545454545454,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 19,
#     'identifier': 19,
#     'relatedNodes': [],
#     'sentence': "Cuomo aims to more than double New York state's solar capacity by the end of 2018.",
#     'sentencePosition': 0.5757575757575758,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 20,
#     'identifier': 20,
#     'relatedNodes': [],
#     'sentence': 'He will also offer incentives to schools and other public buildings that install solar panels on rooftops.',
#     'sentencePosition': 0.6060606060606061,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 21,
#     'identifier': 21,
#     'relatedNodes': [],
#     'sentence': 'In California, the state senate on Wednesday voted to require utility companies to transfer 100 percent of their energy to renewable sources by 2045.',
#     'sentencePosition': 0.6363636363636364,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 22,
#     'identifier': 22,
#     'relatedNodes': [],
#     'sentence': 'Both California and New York require utility companies to shift to 50 percent renewable by 2030.',
#     'sentencePosition': 0.6666666666666666,
#     'source': 'daily-mail'}],
#   '[http://www.dailymail.co.uk/news/article-4564996/Cuomo-orders-WTC-lit-green-support-Paris-Accord.html]': [{'absoluteSentencePosition': 0,
#     'identifier': 0,
#     'relatedNodes': [],
#     'sentence': 'New York Governor Andrew Cuomo ordered two landmarks in his state lit up green late Thursday as a sign of support for the Paris Agreement on climate change – hours after President Donald Trump announced he was pulling the US out of the accord.',
#     'sentencePosition': 0.0,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 1,
#     'identifier': 1,
#     'relatedNodes': [],
#     'sentence': "The antenna atop the World Trade Center in lower Manhattan and the Kosciuszko Bridge linking Brooklyn and Queens were specially lit 'to show our support for the Paris Accord and demonstrate New York's leadership role in protecting our citizens, our environment, and our planet,' Cuomo said in a statement.",
#     'sentencePosition': 0.030303030303030304,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 2,
#     'identifier': 2,
#     'relatedNodes': [],
#     'sentence': 'The World Trade Center is owned by the Port Authority of New York and New Jersey, a government agency jointly controlled by the governors of the two neighboring states.',
#     'sentencePosition': 0.06060606060606061,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 3,
#     'identifier': 3,
#     'relatedNodes': [],
#     'sentence': 'The Kosciuszko Bridge, which spans Newtown Creek and is accessible through the Brooklyn-Queens Expressway, is maintained by the New York State Department of Transportation.',
#     'sentencePosition': 0.09090909090909091,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 4,
#     'identifier': 4,
#     'relatedNodes': [],
#     'sentence': 'Another New York landmark in Lower Manhattan, City Hall, was also lit up in green late Thursday.',
#     'sentencePosition': 0.12121212121212122,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 5,
#     'identifier': 5,
#     'relatedNodes': [],
#     'sentence': 'Mayor Bill de Blasio tweeted a photo of City Hall on Thursday night.',
#     'sentencePosition': 0.15151515151515152,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 6,
#     'identifier': 6,
#     'relatedNodes': [],
#     'sentence': "In the caption, he wrote that New York 'will honor the goals of the Paris Agreement.'",
#     'sentencePosition': 0.18181818181818182,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 7,
#     'identifier': 7,
#     'relatedNodes': [],
#     'sentence': "Earlier on Thursday, de Blasio tweeted that 'opting out of Paris Accord is a grave error.",
#     'sentencePosition': 0.21212121212121213,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 8,
#     'identifier': 8,
#     'relatedNodes': [],
#     'sentence': "'Climate change is real - we feel the effects now.",
#     'sentencePosition': 0.24242424242424243,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 9,
#     'identifier': 9,
#     'relatedNodes': [],
#     'sentence': "Trump's choice ensures it will only get worse.'",
#     'sentencePosition': 0.2727272727272727,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 10,
#     'identifier': 10,
#     'relatedNodes': [],
#     'sentence': 'Cuomo, a Democrat, slammed Trump for pulling out of the agreement.',
#     'sentencePosition': 0.30303030303030304,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 11,
#     'identifier': 11,
#     'relatedNodes': [],
#     'sentence': "'The White House's reckless decision to withdraw from the Paris Accord has devastating repercussions not only for the United States, but for our planet,' the governor said.",
#     'sentencePosition': 0.3333333333333333,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 12,
#     'identifier': 12,
#     'relatedNodes': [],
#     'sentence': "'This administration is abdicating its leadership and taking a backseat to other countries in the global fight against climate change.",
#     'sentencePosition': 0.36363636363636365,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 13,
#     'identifier': 13,
#     'relatedNodes': [],
#     'sentence': "'New York State is committed to meeting the standards set forth in the Paris Accord regardless of Washington's irresponsible actions.",
#     'sentencePosition': 0.3939393939393939,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 14,
#     'identifier': 14,
#     'relatedNodes': [],
#     'sentence': "'We will not ignore the science and reality of climate change.'",
#     'sentencePosition': 0.42424242424242425,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 15,
#     'identifier': 15,
#     'relatedNodes': [],
#     'sentence': "Cuomo also announced that he and two of his fellow governors – California's Jerry Brown and Washington State's Jay Inslee – formed the US Climate Alliance, which will 'convene US states committed to upholding the Paris Climate Agreement and taking aggressive action on climate change.'",
#     'sentencePosition': 0.45454545454545453,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 16,
#     'identifier': 16,
#     'relatedNodes': [],
#     'sentence': "So far, 30 states announced Thursday that they would disregard Trump's order on Thursday and pursue their own policies which seek to limit greenhouse gas emissions, according to The Washington Post.",
#     'sentencePosition': 0.48484848484848486,
#     'source': 'daily-mail'}],
#   '[https://www.theguardian.com/technology/2017/jun/02/shortsighted-wrong-apple-facebook-among-tech-giants-to-reject-paris-pullout]': [{'absoluteSentencePosition': 0,
#     'identifier': 0,
#     'relatedNodes': [],
#     'sentence': 'The heads of some of the largest and most influential American technology companies expressed their “deep disappointment” at Donald Trump’s decision to withdraw the US from the Paris climate accord.',
#     'sentencePosition': 0.0,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 1,
#     'identifier': 1,
#     'relatedNodes': [],
#     'sentence': "Related: President's Paris climate speech annotated: Trump's claims analysed In separate statements and messages on social media, leaders of Apple, Google, Twitter, Amazon, Facebook, Tesla, Microsoft and IBM declared climate change an “urgent” threat that required a global effort to combat.",
#     'sentencePosition': 0.04,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 2,
#     'identifier': 2,
#     'relatedNodes': [],
#     'sentence': '“Decision to withdraw from the #ParisAgreeement was wrong for our planet,” said Apple CEO Tim Cook tweeted on Thursday.',
#     'sentencePosition': 0.08,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 3,
#     'identifier': 3,
#     'relatedNodes': [],
#     'sentence': '“Apple is committed to fight climate change and we will never waver.”',
#     'sentencePosition': 0.12,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 4,
#     'identifier': 4,
#     'relatedNodes': [],
#     'sentence': 'Twitter CEO Jack Dorsey called the decision “incredibly shortsighted” and a “move backwards by the federal government”.',
#     'sentencePosition': 0.16,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 5,
#     'identifier': 5,
#     'relatedNodes': [],
#     'sentence': 'He also retweeted several stories and statements disapproving of Trump’s move to extract the US from the Paris agreement, including a message from the new French president, Emmanuel Macron, that read: Make Our Planet Great Again.',
#     'sentencePosition': 0.2,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 6,
#     'identifier': 6,
#     'relatedNodes': [],
#     'sentence': 'This is an incredibly shortsighted move backwards by the federal government.',
#     'sentencePosition': 0.24,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 7,
#     'identifier': 7,
#     'relatedNodes': [],
#     'sentence': "We're all on this planet together and we need to work together.",
#     'sentencePosition': 0.28,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 8,
#     'identifier': 8,
#     'relatedNodes': [],
#     'sentence': 'https://t.co/tLEdtG0n1o—',
#     'sentencePosition': 0.32,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 9,
#     'identifier': 9,
#     'relatedNodes': [],
#     'sentence': 'jack (@jack) June 1, 2017 Facebook CEO Mark Zuckererg said Trump’s decision “puts our children’s future at risk”.',
#     'sentencePosition': 0.36,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 10,
#     'identifier': 10,
#     'relatedNodes': [],
#     'sentence': 'He said the social media giant was committed to ensuring that every new data center is powered by 100% renewable energy.',
#     'sentencePosition': 0.4,
#     'source': 'the-guardian-uk'}]},
#  {'[http://www.dailymail.co.uk/news/article-4567012/Country-house-used-Rolling-Stones-goes-sale.html,https://www.theguardian.com/world/2017/jun/02/leo-varadkar-becomes-irelands-prime-minister-elect]': [{'absoluteSentencePosition': 0,
#     'identifier': 20,
#     'relatedNodes': [],
#     'sentence': 'The son of an Indian immigrant who came out as gay in 2015 will be the next Irish prime minister, after he was voted leader of the country’s main governing party on Friday.',
#     'sentencePosition': 0.0,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 0,
#     'identifier': 0,
#     'relatedNodes': [],
#     'sentence': 'A quaint country bolthole that was used as a stopover by the Rolling Stones while they played gigs in the west country has been put on the market for £1.1 million.',
#     'sentencePosition': 0.0,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 1,
#     'identifier': 1,
#     'relatedNodes': [],
#     'sentence': "The five-bed home called Pasaderas, which coincidentally means 'stepping stones' in Spanish, played host to the raucous band several times throughout the 1960s.",
#     'sentencePosition': 0.05,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 2,
#     'identifier': 2,
#     'relatedNodes': [],
#     'sentence': 'The unassuming property in the Cotswolds provided the stars with privacy while they performed in the area.',
#     'sentencePosition': 0.1,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 3,
#     'identifier': 3,
#     'relatedNodes': [],
#     'sentence': 'The house belonged to Kerry Hamer, a close friend of the late Stones guitarist Brian Jones who came from nearby Cheltenham.',
#     'sentencePosition': 0.15,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 4,
#     'identifier': 4,
#     'relatedNodes': [],
#     'sentence': "Hamer, a property developer, welcomed the band into Pasederas after a show at the Cheltenham Odeon in 1964 - the year the band's self-titled debut album was released.",
#     'sentencePosition': 0.2,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 5,
#     'identifier': 5,
#     'relatedNodes': [],
#     'sentence': "They returned several times but it's unlikely that Mick Jagger and the rest of the band ever stayed there after June 1969 as by then Jones had been asked to leave the group due to his drug abuse.",
#     'sentencePosition': 0.25,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 6,
#     'identifier': 6,
#     'relatedNodes': [],
#     'sentence': 'The guitarist died less than a month later at the age of 27 by drowning in the swimming pool of his East Sussex home.',
#     'sentencePosition': 0.3,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 7,
#     'identifier': 7,
#     'relatedNodes': [],
#     'sentence': "Pasaderas' surprising rock-and-roll history was uncovered by the current owner, who has now listed it for with estate agents Humberts for £1.1m.",
#     'sentencePosition': 0.35,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 2,
#     'identifier': 22,
#     'relatedNodes': [],
#     'sentence': 'As well as becoming Ireland’s first gay prime minister, Varadkar, 38, will also become the country’s youngest leader, and the first from an ethnic minority background.',
#     'sentencePosition': 0.4,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 13,
#     'identifier': 13,
#     'relatedNodes': [],
#     'sentence': "'The property is spacious and has a great garden, so is the perfect setting for a family.",
#     'sentencePosition': 0.65,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 16,
#     'identifier': 16,
#     'relatedNodes': [],
#     'sentence': 'Inside, the 3,000sq ft property, which has housed a family for the last 40 years, is packed with desirable features such as oak floorboards and a mahogany staircase.',
# ...
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 18,
#     'identifier': 18,
#     'relatedNodes': [],
#     'sentence': 'For a man who has achieved almost everything there is to achieve in the game, this meeting with Juventus offers rare opportunity for the World Player of the Year to step in to new territory.',
#     'sentencePosition': 0.27692307692307694,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 19,
#     'identifier': 19,
#     'relatedNodes': [],
#     'sentence': "Real Madrid are defending champions, Ronaldo's shoot-out penalty clinching victory over neighbours Atletico in Milan last year.",
#     'sentencePosition': 0.2923076923076923,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 20,
#     'identifier': 20,
#     'relatedNodes': [],
#     'sentence': "No team has retained the trophy in the competition's modern form.",
#     'sentencePosition': 0.3076923076923077,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 21,
#     'identifier': 21,
#     'relatedNodes': [],
#     'sentence': 'Real, meanwhile, have not won La Liga and the European Cup in the same season since 1958.',
#     'sentencePosition': 0.3230769230769231,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 22,
#     'identifier': 22,
#     'relatedNodes': [],
#     'sentence': 'So opportunity knocks for Ronaldo.',
#     'sentencePosition': 0.3384615384615385,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 23,
#     'identifier': 23,
#     'relatedNodes': [],
#     'sentence': 'As strange as it sounds, he has not always reached his levels in this fixture.',
#     'sentencePosition': 0.35384615384615387,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 24,
#     'identifier': 24,
#     'relatedNodes': [],
#     'sentence': "In both last year's final and the 2014 success, Ronaldo contributed the closing goal but that masked what were, by his high standards, indifferent evenings on both occasions.",
#     'sentencePosition': 0.36923076923076925,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 25,
#     'identifier': 25,
#     'relatedNodes': [],
#     'sentence': "This time around, against Massimo Allegri's obdurate, dangerous Juventus, Real coach Zinedine Zidane will hope his talisman produces something more consistently effective.",
#     'sentencePosition': 0.38461538461538464,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 26,
#     'identifier': 26,
#     'relatedNodes': [],
#     'sentence': 'Juventus, unlike Atletico, will not allow themselves to be emotionally suffocated by the occasion.',
#     'sentencePosition': 0.4,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 27,
#     'identifier': 27,
#     'relatedNodes': [],
#     'sentence': 'They have already seen off Barcelona in this competition.',
#     'sentencePosition': 0.4153846153846154,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 28,
#     'identifier': 28,
#     'relatedNodes': [],
#     'sentence': 'No, this will have to be a final hard won by Madrid against a side looking to achieve something special themselves, namely an Italian treble.',
#     'sentencePosition': 0.4307692307692308,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 29,
#     'identifier': 29,
#     'relatedNodes': [],
#     'sentence': "Appearing at their team's pre-match press conference on Friday, Juventus goalkeeper Gianluigi Buffon and full-back Dani Alves were both asked several times about Ronaldo.",
#     'sentencePosition': 0.4461538461538462,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 30,
#     'identifier': 30,
#     'relatedNodes': [],
#     'sentence': 'It must be wearing.',
#     'sentencePosition': 0.46153846153846156,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 31,
#     'identifier': 31,
#     'relatedNodes': [],
#     'sentence': "Buffon described the Portuguese as a 'sporting model' while Alves said he wouldn't dream of putting himself 'on the same pedestal'.",
#     'sentencePosition': 0.47692307692307695,
#     'source': 'daily-mail'},
#    {'absoluteSentencePosition': 32,
#     'identifier': 32,
#     'relatedNodes': [],
#     'sentence': "All very nice but what will concern both – and indeed Allegri – is Ronaldo's form.",
#     'sentencePosition': 0.49230769230769234,
#     'source': 'daily-mail'}],
#   '[https://www.theguardian.com/football/2017/jun/02/champions-league-final-cardiff-real-madrid-juventus-history-gareth-bale-ronaldo-buffon-alves]': [{'absoluteSentencePosition': 0,
#     'identifier': 0,
#     'relatedNodes': [],
#     'sentence': 'Sergio Ramos described it as a “date with history”, and it is one they have waited a long time for.',
#     'sentencePosition': 0.0,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 1,
#     'identifier': 1,
#     'relatedNodes': [],
#     'sentence': 'The last time Real Madrid were in this position, Alfredo Di Stéfano played his final game for the club, departing bitterly after defeat by Helenio Herrera’s Internazionale.',
#     'sentencePosition': 0.010526315789473684,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 2,
#     'identifier': 2,
#     'relatedNodes': [],
#     'sentence': 'Two years before, Ferenc Puskas scored three, but Eusebio’s goal denied them in Amsterdam; and the time before that, the last time they achieved what they seek to emulate tomorrow, Paco Gento’s extra-time winner defeated Milan 3-2 at the Heysel Stadium.',
#     'sentencePosition': 0.021052631578947368,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 3,
#     'identifier': 3,
#     'relatedNodes': [],
#     'sentence': 'That was 59 years ago now, victory securing Madrid’s players 50,000 pesetas each, 25,000 per trophy: the bachelors earned £20 a month, married players £29, but all of them left Belgium £148 better off.',
#     'sentencePosition': 0.031578947368421054,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 4,
#     'identifier': 4,
#     'relatedNodes': [],
#     'sentence': 'They had earned it: Madrid had just completed a league and European Cup double.',
#     'sentencePosition': 0.042105263157894736,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 5,
#     'identifier': 5,
#     'relatedNodes': [],
#     'sentence': 'It had happened before, in each of the two previous years, but it never happened again.',
#     'sentencePosition': 0.05263157894736842,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 6,
#     'identifier': 6,
#     'relatedNodes': [],
#     'sentence': 'Until now?',
#     'sentencePosition': 0.06315789473684211,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 7,
#     'identifier': 7,
#     'relatedNodes': [],
#     'sentence': 'Madrid have won 27 league titles since and eight European Cups, but not in the same season.',
#     'sentencePosition': 0.07368421052631578,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 8,
#     'identifier': 8,
#     'relatedNodes': [],
#     'sentence': 'Like in 1964 and 1962, they are 90 minutes away.',
#     'sentencePosition': 0.08421052631578947,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 9,
#     'identifier': 9,
#     'relatedNodes': [],
#     'sentence': 'Inter and Benfica denied them then; Juventus stand before them and history now – and “history”, as Ramos said, really is the word, even for the biggest, most successful club there is.',
#     'sentencePosition': 0.09473684210526316,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 10,
#     'identifier': 10,
#     'relatedNodes': [],
#     'sentence': 'Madrid have won 12 European Cups, but the last eight have come alone, stretching back to Brussels.',
#     'sentencePosition': 0.10526315789473684,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 11,
#     'identifier': 11,
#     'relatedNodes': [],
#     'sentence': 'These players could achieve what Puskas, Amancio, Sánchez, Butragueno, Zidane, and the original Ronaldo never did.',
#     'sentencePosition': 0.11578947368421053,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 14,
#     'identifier': 14,
#     'relatedNodes': [],
#     'sentence': '“Our history is not coincidence. or us this is an opportunity that this wonderful sport gives us.”',
#     'sentencePosition': 0.14736842105263157,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 16,
#     'identifier': 16,
#     'relatedNodes': [],
#     'sentence': 'It is an opportunity to eclipse some of their most successful generations.',
#     'sentencePosition': 0.16842105263157894,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 17,
#     'identifier': 17,
#     'relatedNodes': [],
#     'sentence': 'To do what Di Stéfano, Rial and Gento did.',
#     'sentencePosition': 0.17894736842105263,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 18,
#     'identifier': 18,
#     'relatedNodes': [],
#     'sentence': 'Much has changed since then, a long time has passed, a lot of players.',
#     'sentencePosition': 0.18947368421052632,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 19,
#     'identifier': 19,
#     'relatedNodes': [],
#     'sentence': 'These are different days.',
#     'sentencePosition': 0.2,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 20,
#     'identifier': 20,
#     'relatedNodes': [],
#     'sentence': 'Pepe Santamaría recalled that the bonus “didn’t go far”.',
#     'sentencePosition': 0.21052631578947367,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 21,
#     'identifier': 21,
#     'relatedNodes': [],
#     'sentence': 'Yesterday, Juventus’s Dani Alves grinned that cheeky grin and said: “the president promised us a red horse [a Ferrari] if we win – let’s see if he delivers.”',
#     'sentencePosition': 0.22105263157894736,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 22,
#     'identifier': 22,
#     'relatedNodes': [],
#     'sentence': 'Madrid’s bonus is reportedly 1.5m euros each.',
#     'sentencePosition': 0.23157894736842105,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 23,
#     'identifier': 23,
#     'relatedNodes': [],
#     'sentence': 'The enormity of the achievement warrants it, even for them.',
#     'sentencePosition': 0.24210526315789474,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 24,
#     'identifier': 24,
#     'relatedNodes': [],
#     'sentence': 'After all, it is not just 1958, not just a wait of over half a century for this double; it is that another record stands before them: 25 years have passed since a team defended the European title.',
#     'sentencePosition': 0.25263157894736843,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 25,
#     'identifier': 25,
#     'relatedNodes': [],
#     'sentence': '“This is a chance to win it for a second year in a row,” Ramos said.',
#     'sentencePosition': 0.2631578947368421,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 26,
#     'identifier': 26,
#     'relatedNodes': [],
#     'sentence': 'Back then, Carlo Ancelotti, the man who led Madrid to the décima, their 10th European Cup three years ago, was on the pitch.',
#     'sentencePosition': 0.2736842105263158,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 27,
#     'identifier': 27,
#     'relatedNodes': [],
#     'sentence': 'So were Ruud Gullit, Frank Rijkaard and Marco van Basten.',
#     'sentencePosition': 0.28421052631578947,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 28,
#     'identifier': 28,
#     'relatedNodes': [],
#     'sentence': 'In the Champions League era, no team has emulated that Milan team, not even those that have defined epochs like Arrigo Sacchi’s side did.',
#     'sentencePosition': 0.29473684210526313,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 29,
#     'identifier': 29,
#     'relatedNodes': [],
#     'sentence': 'Madrid’s opponents, Juventus, have been in consecutive finals but, having won it in 1996, in 1997 and 1998 they were defeated – as they would be again in 2003 and 2015.',
#     'sentencePosition': 0.30526315789473685,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 30,
#     'identifier': 30,
#     'relatedNodes': [],
#     'sentence': 'Related: Cult of Cristiano Ronaldo distracts from Real Madrid’s brilliance | Barney Ronay “Real Madrid have a feeling with finals; they are used to winning them,” Gigi Buffon said, smiling slightly.',
#     'sentencePosition': 0.3157894736842105,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 31,
#     'identifier': 31,
#     'relatedNodes': [],
#     'sentence': '“We, on the other hand, have lost a lot of finals.”',
#     'sentencePosition': 0.3263157894736842,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 32,
#     'identifier': 32,
#     'relatedNodes': [],
#     'sentence': 'For Madrid, it is 11 wins from 13, and three finals in four years, something Ramos described as “barbaric”.',
#     'sentencePosition': 0.3368421052631579,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 33,
#     'identifier': 33,
#     'relatedNodes': [],
#     'sentence': 'For Juventus, it is two from eight.',
#     'sentencePosition': 0.3473684210526316,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 34,
#     'identifier': 34,
#     'relatedNodes': [],
#     'sentence': '“We are going try to change our history,” Buffon added.',
#     'sentencePosition': 0.35789473684210527,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 35,
#     'identifier': 35,
#     'relatedNodes': [],
#     'sentence': 'At 39, it could be his last opportunity: this is the only trophy he has not won.',
#     'sentencePosition': 0.3684210526315789,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 36,
#     'identifier': 36,
#     'relatedNodes': [],
#     'sentence': 'The last time he tried, Juve were beaten by Barcelona.',
#     'sentencePosition': 0.37894736842105264,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 37,
#     'identifier': 37,
#     'relatedNodes': [],
#     'sentence': 'That night in Berlin, Dani Alves played for the other side, collecting his third European Cup; now of course he is a team-mate.',
#     'sentencePosition': 0.3894736842105263,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 38,
#     'identifier': 38,
#     'relatedNodes': [],
#     'sentence': '“I’d like to see him win it; I took one off them, I’d like to give one back,” Alves said.',
#     'sentencePosition': 0.4,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 39,
#     'identifier': 39,
#     'relatedNodes': [],
#     'sentence': 'Buffon meanwhile admitted: “I asked Dani to teach us how to win this competition.”',
#     'sentencePosition': 0.4105263157894737,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 40,
#     'identifier': 40,
#     'relatedNodes': [],
#     'sentence': '“There is a thorn in Juventus’s side,” Alves said.',
#     'sentencePosition': 0.42105263157894735,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 41,
#     'identifier': 41,
#     'relatedNodes': [],
#     'sentence': '“Whether that’s because they lost that final two years ago, or that it is twenty years since they won this competition, or that they lost the 1998 final to an offside goal …” The “offside” goal, cheekily referenced, was scored by Pedja Mijatovic, to finally end Madrid’s 32-year wait for the trophy that despite those barren years had come to define them.',
#     'sentencePosition': 0.43157894736842106,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 42,
#     'identifier': 42,
#     'relatedNodes': [],
#     'sentence': 'Alves was enjoying this, a moment for fun, not for fear.',
#     'sentencePosition': 0.4421052631578947,
#     'source': 'the-guardian-uk'},
#    {'absoluteSentencePosition': 43,
#     'identifier': 43,
#     'relatedNodes': [],
#     'sentence': '“We are not scared of Madrid’s history,” he added.',
#     'sentencePosition': 0.45263157894736844,
#     'source': 'the-guardian-uk'}]}]

# %%
print(articles.count())
# Out:
# 8856
